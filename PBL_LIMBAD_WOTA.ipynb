# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Data Engineer**

# %%
#Sumber data yang digunakan
path_od = "https://raw.githubusercontent.com/adityapbx/PBL/refs/heads/main/order_detail.csv"
path_pd = "https://raw.githubusercontent.com/adityapbx/PBL/refs/heads/main/payment_detail.csv"
path_cd = "https://raw.githubusercontent.com/adityapbx/PBL/refs/heads/main/customer_detail.csv"
path_sd = "https://raw.githubusercontent.com/adityapbx/PBL/refs/heads/main/sku_detail.csv"
df_od = pd.read_csv(path_od)
df_pd = pd.read_csv(path_pd)
df_cd = pd.read_csv(path_cd)
df_sd = pd.read_csv(path_sd)

# %%
#Mengampilkan 5 baris pertama tabel order_detail
df_od.head()
# Out:
#                id customer_id  order_date   sku_id    price  qty_ordered  \
# 0  ODR9939707760w    C713589L  2021-11-19  P858068    26100          200
# 1  ODR7448356649d    C551551L  2021-11-19  P886455  1971942            5
# 2  ODR4011281866z    C685596L  2021-11-25  P678648  7482000            1
# 3  ODR3378927994s    C830683L  2021-11-22  P540013  3593680            1
# 4  ODR4904430099k    C191766L  2021-11-21  P491032  4413220            1
#
#    before_discount  discount_amount  after_discount  is_gross  is_valid  \
# 0        5220000.0       2610000.00      2610000.00         1         1
# 1        9859710.0       2464927.50      7394782.50         1         0
# 2        7482000.0       2065344.62      5416655.38         1         0
# 3        3593680.0       1455440.40      2138239.60         1         1
# 4        4413220.0       1059172.80      3354047.20         1         1
#
#    is_net  payment_id
# 0       0           5
# 1       0           5
# 2       0           4
# 3       1           5
# 4       1           4

# %%
#Menampilkan informasi mengenai missing value pada dataframe
print("Order Details")
df_od.info()
print("")
print("Payment Details")
df_pd.info()
print("")
print("Customer Details")
df_cd.info()
print("")
print("SKU Details")
df_sd.info()
# Out:
# Order Details
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5884 entries, 0 to 5883
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               5884 non-null   object
#  1   customer_id      5884 non-null   object
#  2   order_date       5884 non-null   object
#  3   sku_id           5884 non-null   object
#  4   price            5884 non-null   int64
#  5   qty_ordered      5884 non-null   int64
#  6   before_discount  5884 non-null   float64
#  7   discount_amount  5884 non-null   float64
#  8   after_discount   5884 non-null   float64
#  9   is_gross         5884 non-null   int64
#  10  is_valid         5884 non-null   int64
#  11  is_net           5884 non-null   int64
#  12  payment_id       5884 non-null   int64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 597.7+ KB
#
# Payment Details
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              16 non-null     int64
#  1   payment_method  16 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 384.0+ bytes
#
# Customer Details
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3998 non-null   object
#  1   registered_date  3998 non-null   object
# dtypes: object(2)
# memory usage: 62.6+ KB
#
# SKU Details
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3206 entries, 0 to 3205
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          3206 non-null   object
#  1   sku_name    3206 non-null   object
#  2   base_price  3206 non-null   float64
#  3   cogs        3206 non-null   int64
#  4   category    3206 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 125.4+ KB

# %%
#Menjalankan SQL di Colab
from sqlite3 import connect
conn = connect(':memory:')
df_od.to_sql('order_detail',conn, index=False, if_exists='replace')
df_pd.to_sql('payment_detail', conn, index=False, if_exists='replace')
df_sd.to_sql('sku_detail', conn, index=False, if_exists='replace')
df_cd.to_sql('customer_detail', conn, index=False, if_exists='replace')
# Out:
# 3998

# %%
#Query SQL untuk menggabungkan data
df = pd.read_sql("""
SELECT
    order_detail.*,
    payment_detail.payment_method,
    sku_detail.sku_name,
    sku_detail.base_price,
    sku_detail.cogs,
    sku_detail.category,
    customer_detail.registered_date
FROM order_detail
LEFT JOIN payment_detail
    on payment_detail.id = order_detail.payment_id
LEFT JOIN sku_detail
    on sku_detail.id = order_detail.sku_id
LEFT JOIN customer_detail
    on customer_detail.id = order_detail.customer_id
""", conn)

# %% [markdown]
# ![SKEMA RELASIONAL E-COMMERCE.png](data:image/png;base64,...)

# %%
#Mengampilkan 5 baris pertama tabel order_detail setalah dilakukan relational di mysql
df_od.head()
# Out:
#                id customer_id  order_date   sku_id    price  qty_ordered  \
# 0  ODR9939707760w    C713589L  2021-11-19  P858068    26100          200
# 1  ODR7448356649d    C551551L  2021-11-19  P886455  1971942            5
# 2  ODR4011281866z    C685596L  2021-11-25  P678648  7482000            1
# 3  ODR3378927994s    C830683L  2021-11-22  P540013  3593680            1
# 4  ODR4904430099k    C191766L  2021-11-21  P491032  4413220            1
#
#    before_discount  discount_amount  after_discount  is_gross  is_valid  \
# 0        5220000.0       2610000.00      2610000.00         1         1
# 1        9859710.0       2464927.50      7394782.50         1         0
# 2        7482000.0       2065344.62      5416655.38         1         0
# 3        3593680.0       1455440.40      2138239.60         1         1
# 4        4413220.0       1059172.80      3354047.20         1         1
#
#    is_net  payment_id
# 0       0           5
# 1       0           5
# 2       0           4
# 3       1           5
# 4       1           4

# %%
#Menampikan tipe data tiap kolom
df.dtypes
# Out:
# id                  object
# customer_id         object
# order_date          object
# sku_id              object
# price                int64
# qty_ordered          int64
# before_discount    float64
# discount_amount    float64
# after_discount     float64
# is_gross             int64
# is_valid             int64
# is_net               int64
# payment_id           int64
# payment_method      object
# sku_name            object
# base_price         float64
# cogs                 int64
# category            object
# registered_date     object
# dtype: object

# %%
#Mengubah tipe kolom Date menjadi Datetime
df['order_date']= pd.to_datetime(df['order_date'])
df['registered_date']= pd.to_datetime(df['registered_date'])
df.dtypes
# Out:
# id                         object
# customer_id                object
# order_date         datetime64[ns]
# sku_id                     object
# price                       int64
# qty_ordered                 int64
# before_discount           float64
# discount_amount           float64
# after_discount            float64
# is_gross                    int64
# is_valid                    int64
# is_net                      int64
# payment_id                  int64
# payment_method             object
# sku_name                   object
# base_price                float64
# cogs                        int64
# category                   object
# registered_date    datetime64[ns]
# dtype: object

# %%
#Mengubah tipe data before_discount,discount_amount,after_discount,dan base_price menjadi int agar mudah dilakukan pengolahan data
df = df.astype({"before_discount":'int', "discount_amount":'int', "after_discount":'int',"base_price":'int'})
df.dtypes
# Out:
# id                         object
# customer_id                object
# order_date         datetime64[ns]
# sku_id                     object
# price                       int64
# qty_ordered                 int64
# before_discount             int64
# discount_amount             int64
# after_discount              int64
# is_gross                    int64
# is_valid                    int64
# is_net                      int64
# payment_id                  int64
# payment_method             object
# sku_name                   object
# base_price                  int64
# cogs                        int64
# category                   object
# registered_date    datetime64[ns]
# dtype: object

# %%
# Menghapus baris pada semua kolom yang mempunyai nilai discount_amount dibawah nol
df = df[df['discount_amount'] >= 0]

# %%
# Cek duplikat dari setiap kolom
for col in df.columns:
    print(f"Duplikat pada kolom '{col}': {df.duplicated(subset=[col]).sum()}")
# Out:
# Duplikat pada kolom 'id': 120
# Duplikat pada kolom 'customer_id': 1885
# Duplikat pada kolom 'order_date': 5474
# Duplikat pada kolom 'sku_id': 2677
# Duplikat pada kolom 'price': 4234
# Duplikat pada kolom 'qty_ordered': 5844
# Duplikat pada kolom 'before_discount': 3963
# Duplikat pada kolom 'discount_amount': 5714
# Duplikat pada kolom 'after_discount': 3860
# Duplikat pada kolom 'is_gross': 5882
# Duplikat pada kolom 'is_valid': 5881
# Duplikat pada kolom 'is_net': 5881
# Duplikat pada kolom 'payment_id': 5867
# Duplikat pada kolom 'payment_method': 5867
# Duplikat pada kolom 'sku_name': 2677
# Duplikat pada kolom 'base_price': 4380
# Duplikat pada kolom 'cogs': 3412
# Duplikat pada kolom 'category': 5868
# Duplikat pada kolom 'registered_date': 5494

# %%
# Drop duplicates based on the 'id' column
df = df.drop_duplicates(subset=['id'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5763 entries, 0 to 5882
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               5763 non-null   object
#  1   customer_id      5763 non-null   object
#  2   order_date       5763 non-null   datetime64[ns]
#  3   sku_id           5763 non-null   object
#  4   price            5763 non-null   int64
#  5   qty_ordered      5763 non-null   int64
#  6   before_discount  5763 non-null   int64
#  7   discount_amount  5763 non-null   int64
#  8   after_discount   5763 non-null   int64
#  9   is_gross         5763 non-null   int64
#  10  is_valid         5763 non-null   int64
#  11  is_net           5763 non-null   int64
#  12  payment_id       5763 non-null   int64
#  13  payment_method   5763 non-null   object
#  14  sku_name         5763 non-null   object
#  15  base_price       5763 non-null   int64
#  16  cogs             5763 non-null   int64
#  17  category         5763 non-null   object
#  18  registered_date  5763 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(11), object(6)
# memory usage: 900.5+ KB

# %% [markdown]
# # **Data Analyst**

# %%
df['after_discount'].describe()
# Out:
# count    5.763000e+03
# mean     1.477507e+06
# std      1.011936e+07
# min      0.000000e+00
# 25%      9.274200e+04
# 50%      2.436000e+05
# 75%      1.218000e+06
# max      5.187520e+08
# Name: after_discount, dtype: float64

# %%
df['discount_amount'].describe()
# Out:
# count    5.763000e+03
# mean     5.766924e+03
# std      6.891017e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.610000e+06
# Name: discount_amount, dtype: float64

# %%
# Tambahkan kolom bulan
df['month'] = df['order_date'].dt.to_period('M')  # Format periode bulanan

# Total diskon per bulan
monthly_discount = df.groupby('month')['discount_amount'].sum()

# Hitung persentase setiap bulan
total_discount = monthly_discount.sum()
monthly_discount_percentage = (monthly_discount / total_discount) * 100

# Plot bar chart
plt.figure(figsize=(10, 6))
monthly_discount_percentage.plot(kind='bar', color='skyblue', edgecolor='black')

# Tambahkan nilai persentase di atas masing-masing batang
for i, perc in enumerate(monthly_discount_percentage):
    plt.text(i, perc + 1, f'{perc:.1f}%', ha='center', fontsize=12)

# Menambahkan informasi ke grafik
plt.title('Persentase Discount Amount per Bulan', fontsize=16)
plt.xlabel('Bulan', fontsize=14)
plt.ylabel('Persentase (%)', fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Tampilkan plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Data Scientist**

# %%
from pycaret.time_series import *

# %%
# Aggregate 'discount_amount' by 'order_date' (using sum in this example)
#df_aggregated = df.groupby('order_date')['discount_amount'].sum().reset_index()

# Aggregate the data by month
df_aggregated = df.groupby(pd.Grouper(key='order_date', freq='M'))['discount_amount'].sum().reset_index()


# Set 'order_date' as the index
df_aggregated.set_index('order_date', inplace=True)
df_aggregated = df_aggregated.sort_index()

# %%
# Add a frequency to your time series
#df_aggregated = df_aggregated.asfreq('M')

# %%
#df_disc = df[['discount_amount']]

# Inisialisasi forecasting
exp = setup(data=df_aggregated,
            target='discount_amount',
            session_id=123, # Untuk reproduksi
            fold=2,         # Cross-validation
            fh=6,          # Forecast horizon (contoh: 12 periode ke depan)
            seasonal_period=12, # Jika data musiman (bulanan: 12, mingguan: 7, dsb.)
            numeric_imputation_target='mean')
# Out:
# <style type="text/css">
# #T_18dca_row28_col1, #T_18dca_row31_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_18dca" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18dca_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_18dca_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18dca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18dca_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_18dca_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_18dca_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_18dca_row1_col1" class="data row1 col1" >discount_amount</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_18dca_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_18dca_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_18dca_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_18dca_row3_col1" class="data row3 col1" >Not Present</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_18dca_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_18dca_row4_col1" class="data row4 col1" >(24, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_18dca_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_18dca_row5_col1" class="data row5 col1" >(24, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_18dca_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_18dca_row6_col1" class="data row6 col1" >(18, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_18dca_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_18dca_row7_col1" class="data row7 col1" >(6, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_18dca_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_18dca_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_18dca_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_18dca_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_18dca_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_18dca_row10_col1" class="data row10 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_18dca_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_18dca_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_18dca_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_18dca_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_18dca_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_18dca_row13_col1" class="data row13 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_18dca_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_18dca_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_18dca_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_18dca_row15_col1" class="data row15 col1" >user_defined</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_18dca_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_18dca_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_18dca_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_18dca_row17_col1" class="data row17 col1" >[12]</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_18dca_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_18dca_row18_col1" class="data row18 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_18dca_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_18dca_row19_col1" class="data row19 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_18dca_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_18dca_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_18dca_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_18dca_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_18dca_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_18dca_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_18dca_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_18dca_row23_col1" class="data row23 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_18dca_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_18dca_row24_col1" class="data row24 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_18dca_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_18dca_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_18dca_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_18dca_row26_col1" class="data row26 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_18dca_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_18dca_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_18dca_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_18dca_row28_col1" class="data row28 col1" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_18dca_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_18dca_row29_col1" class="data row29 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_18dca_level

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_969ce th {
#   text-align: left;
# }
# #T_969ce_row0_col0, #T_969ce_row0_col2, #T_969ce_row0_col3, #T_969ce_row0_col4, #T_969ce_row0_col5, #T_969ce_row0_col7, #T_969ce_row1_col0, #T_969ce_row1_col1, #T_969ce_row1_col2, #T_969ce_row1_col4, #T_969ce_row1_col5, #T_969ce_row1_col6, #T_969ce_row1_col7, #T_969ce_row2_col0, #T_969ce_row2_col1, #T_969ce_row2_col2, #T_969ce_row2_col3, #T_969ce_row2_col4, #T_969ce_row2_col5, #T_969ce_row2_col6, #T_969ce_row2_col7, #T_969ce_row3_col0, #T_969ce_row3_col1, #T_969ce_row3_col2, #T_969ce_row3_col3, #T_969ce_row3_col4, #T_969ce_row3_col5, #T_969ce_row3_col6, #T_969ce_row3_col7, #T_969ce_row4_col0, #T_969ce_row4_col1, #T_969ce_row4_col2, #T_969ce_row4_col3, #T_969ce_row4_col4, #T_969ce_row4_col6, #T_969ce_row4_col7, #T_969ce_row5_col0, #T_969ce_row5_col1, #T_969ce_row5_col2, #T_969ce_row5_col3, #T_969ce_row5_col4, #T_969ce_row5_col5, #T_969ce_row5_col6, #T_969ce_row5_col7, #T_969ce_row6_col0, #T_969ce_row6_col1, #T_969ce_row6_col3, #T_969ce_row6_col5, #T_969ce_row6_col6, #T_969ce_row7_col0, #T_969ce_row7_col1, #T_969ce_row7_col2, #T_969ce_row7_col3, #T_969ce_row7_col4, #T_969ce_row7_col5, #T_969ce_row7_col6, #T_969ce_row7_col7, #T_969ce_row8_col0, #T_969ce_row8_col1, #T_969ce_row8_col2, #T_969ce_row8_col3, #T_969ce_row8_col4, #T_969ce_row8_col5, #T_969ce_row8_col6, #T_969ce_row8_col7, #T_969ce_row9_col0, #T_969ce_row9_col1, #T_969ce_row9_col2, #T_969ce_row9_col3, #T_969ce_row9_col4, #T_969ce_row9_col5, #T_969ce_row9_col6, #T_969ce_row9_col7, #T_969ce_row10_col0, #T_969ce_row10_col1, #T_969ce_row10_col2, #T_969ce_row10_col3, #T_969ce_row10_col4, #T_969ce_row10_col5, #T_969ce_row10_col6, #T_969ce_row10_col7, #T_969ce_row11_col0, #T_969ce_row11_col1, #T_969ce_row11_col2, #T_969ce_row11_col3, #T_969ce_row11_col4, #T_969ce_row11_col5, #T_969ce_row11_col6, #T_969ce_row11_col7, #T_969ce_row12_col0, #T_969ce_row12_col1, #T_969ce_row12_col2, #T_969ce_row12_col3, #T_969ce_row12_col4, #T_969ce_row12_col5, #T_969ce_row12_col6, #T_969ce_row12_col7, #T_969ce_row13_col0, #T_969ce_row13_col1, #T_969ce_row13_col2, #T_969ce_row13_col3, #T_969ce_row13_col4, #T_969ce_row13_col5, #T_969ce_row13_col6, #T_969ce_row13_col7, #T_969ce_row14_col0, #T_969ce_row14_col1, #T_969ce_row14_col2, #T_969ce_row14_col3, #T_969ce_row14_col4, #T_969ce_row14_col5, #T_969ce_row14_col6, #T_969ce_row14_col7, #T_969ce_row15_col0, #T_969ce_row15_col1, #T_969ce_row15_col2, #T_969ce_row15_col3, #T_969ce_row15_col4, #T_969ce_row15_col5, #T_969ce_row15_col6, #T_969ce_row15_col7, #T_969ce_row16_col0, #T_969ce_row16_col1, #T_969ce_row16_col2, #T_969ce_row16_col3, #T_969ce_row16_col4, #T_969ce_row16_col5, #T_969ce_row16_col6, #T_969ce_row16_col7, #T_969ce_row17_col0, #T_969ce_row17_col1, #T_969ce_row17_col2, #T_969ce_row17_col3, #T_969ce_row17_col4, #T_969ce_row17_col5, #T_969ce_row17_col6, #T_969ce_row17_col7, #T_969ce_row18_col0, #T_969ce_row18_col1, #T_969ce_row18_col2, #T_969ce_row18_col3, #T_969ce_row18_col4, #T_969ce_row18_col5, #T_969ce_row18_col6, #T_969ce_row18_col7, #T_969ce_row19_col0, #T_969ce_row19_col1, #T_969ce_row19_col2, #T_969ce_row19_col3, #T_969ce_row19_col4, #T_969ce_row19_col5, #T_969ce_row19_col6, #T_969ce_row19_col7, #T_969ce_row20_col0, #T_969ce_row20_col1, #T_969ce_row20_col2, #T_969ce_row20_col3, #T_969ce_row20_col4, #T_969ce_row20_col5, #T_969ce_row20_col6, #T_969ce_row20_col7, #T_969ce_row21_col0, #T_969ce_row21_col1, #T_969ce_row21_col2, #T_969ce_row21_col3, #T_969ce_row21_col4, #T_969ce_row21_col5, #T_969ce_row21_col6, #T_969ce_row21_col7, #T_969ce_row22_col0, #T_969ce_row22_col1, #T_969ce_row22_col2, #T_969ce_row22_col3, #T_969ce_row22_col4, #T_969ce_row22_col5, #T_969ce_row22_col6, #T_969ce_row22_col7, #T_969ce_row23_col0, #T_969ce_row23_col1, #T_969ce_row23_col2, #T_969ce_row23_col3, #T_969ce_row23_col4, #T_969ce_row23_col5, #T_969ce_row23_col6, #T_969ce_row23_col7, #T_969ce_row24_col0, #T_969ce_row24_col1, #T_969ce_row24_col2, #T_969ce_row24_col3, #T_969ce_row24_col4, #T_969ce_row24_col5, #T_969ce_row24_col6, #T_969ce_row24_col7 {
#   text-align: left;
# }
# #T_969ce_row0_col1, #T_969ce_row0_col6, #T_969ce_row1_col3, #T_969ce_row4_col5, #T_969ce_row6_col2, #T_969ce_row6_col4, #T_969ce_row6_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_969ce_row0_col8, #T_969ce_row1_col8, #T_969ce_row2_col8, #T_969ce_row3_col8, #T_969ce_row4_col8, #T_969ce_row5_col8, #T_969ce_row7_col8, #T_969ce_row8_col8, #T_969ce_row9_col8, #T_969ce_row10_col8, #T_969ce_row11_col8, #T_969ce_row12_col8, #T_969ce_row13_col8, #T_969ce_row14_col8, #T_969ce_row15_col8, #T_969ce_row16_col8, #T_969ce_row17_col8, #T_969ce_row18_col8, #T_969ce_row19_col8, #T_969ce_row20_col8, #T_969ce_row21_col8, #T_969ce_row22_col8, #T_969ce_row23_col8, #T_969ce_row24_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_969ce_row6_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_969ce" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_969ce_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_969ce_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_969ce_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_969ce_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_969ce_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_969ce_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_969ce_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_969ce_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_969ce_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_969ce_level0_row0" class="row_heading level0 row0" >arima</th>
#       <td id="T_969ce_row0_col0" class="data row0 col0" >ARIMA</td>
#       <td id="T_969ce_row0_col1" class="data row0 col1" >9.5865</td>
#       <td id="T_969ce_row0_col2" class="data row0 col2" >11.6000</td>
#       <td id="T_969ce_row0_col3" class="data row0 col3" >1933290.7269</td>
#       <td id="T_969ce_row0_col4" class="data row0 col4" >3814994.6182</td>
#       <td id="T_969ce_row0_col5" class="data row0 col5" >1.9146</td>
#       <td id="T_969ce_row0_col6" class="data row0 col6" >0.9582</td>
#       <td id="T_969ce_row0_col7" class="data row0 col7" >-0.1304</td>
#       <td id="T_969ce_row0_col8" class="data row0 col8" >0.1600</td>
#     </tr>
#     <tr>
#       <th id="T_969ce_level0_row1" class="row_heading level0 row1" >grand_means</th>
#       <td id="T_969ce_row1_col0" class="data row1 col0" >Grand Means Forecaster</td>
#       <td id="T_969ce_row1_col1" class="data row1 col1" >9.6166</td>
#       <td id="T_969ce_row1_col2" class="data row1 col2" >11.5388</td>
#       <td id="T_969ce_row1_col3" class="data row1 col3" >1925329.4444</td>
#       <td id="T_969ce_row1_col4" class="data row1 col4" >3790845.5649</td>
#       <td id="T_969ce_row1_col5" class="data row1 col5" >3.2838</td>
#       <td id="T_969ce_row1_col6" class="data row1 col6" >1.0336</td>
#       <td id="T_969ce_row1_col7" class="data row1 col7" >-0.1118</td>
#       <td id="T_969ce_row1_col8" class="data row1 col8" >0.1000</td>
#     </tr>
#     <tr>
#       <th id="T_969ce_level0_row2" class="row_heading level0 row2" >naive</th>
#       <td id="T_969ce_row2_col0" class="data row2 col0" >Naive Forecaster</td>
#       <td id="T_969ce_row2_col1" class="data row2 col1" >9.6548</td>
#       <td id="T_969ce_row2_col2" class="data row2 col2" >11.6530</td>
#       <td id="T_969ce_row2_col3" class="data row2 col3" >2155126.0000</td>
#       <td id="T_969ce_row2_col4" class="data row2 col4" >4190074.9815</td>
#       <td id="T_969ce_row2_col5" class="data row2 col5" >1.5218</td>
#       <td id="T_969ce_row2_col6" class="data row2 col6" >1.5217</td>
#       <td id="T_969ce_row2_col7" class="data row2 col7" >-0.9227</td>
#       <td id="T_969ce_row2_col8" class="data row2 col8" >0.0850</td>
#     </tr>
#     <tr>
#       <t
# Processing:   0%|          | 0/109 [00:00<?, ?it/s]

# %%
print(best_model)
# Out:
# ARIMA()

# %%
final_model = create_model(best_model)
# Out:
# <style type="text/css">
# #T_03b05_row2_col0, #T_03b05_row2_col1, #T_03b05_row2_col2, #T_03b05_row2_col3, #T_03b05_row2_col4, #T_03b05_row2_col5, #T_03b05_row2_col6, #T_03b05_row2_col7 {
#   background: yellow;
# }
# </style>
# <table id="T_03b05" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03b05_level0_col0" class="col_heading level0 col0" >cutoff</th>
#       <th id="T_03b05_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_03b05_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_03b05_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_03b05_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_03b05_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_03b05_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_03b05_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03b05_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03b05_row0_col0" class="data row0 col0" >2021-06</td>
#       <td id="T_03b05_row0_col1" class="data row0 col1" >18.7907</td>
#       <td id="T_03b05_row0_col2" class="data row0 col2" >23.0076</td>
#       <td id="T_03b05_row0_col3" class="data row0 col3" >2712531.7385</td>
#       <td id="T_03b05_row0_col4" class="data row0 col4" >6350089.6718</td>
#       <td id="T_03b05_row0_col5" class="data row0 col5" >1.9143</td>
#       <td id="T_03b05_row0_col6" class="data row0 col6" >1.0943</td>
#       <td id="T_03b05_row0_col7" class="data row0 col7" >-0.2184</td>
#     </tr>
#     <tr>
#       <th id="T_03b05_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_03b05_row1_col0" class="data row1 col0" >2021-12</td>
#       <td id="T_03b05_row1_col1" class="data row1 col1" >0.3824</td>
#       <td id="T_03b05_row1_col2" class="data row1 col2" >0.1925</td>
#       <td id="T_03b05_row1_col3" class="data row1 col3" >1154049.7153</td>
#       <td id="T_03b05_row1_col4" class="data row1 col4" >1279899.5647</td>
#       <td id="T_03b05_row1_col5" class="data row1 col5" >1.9148</td>
#       <td id="T_03b05_row1_col6" class="data row1 col6" >0.8220</td>
#       <td id="T_03b05_row1_col7" class="data row1 col7" >-0.0425</td>
#     </tr>
#     <tr>
#       <th id="T_03b05_level0_row2" class="row_heading level0 row2" >Mean</th>
#       <td id="T_03b05_row2_col0" class="data row2 col0" >NaT</td>
#       <td id="T_03b05_row2_col1" class="data row2 col1" >9.5865</td>
#       <td id="T_03b05_row2_col2" class="data row2 col2" >11.6000</td>
#       <td id="T_03b05_row2_col3" class="data row2 col3" >1933290.7269</td>
#       <td id="T_03b05_row2_col4" class="data row2 col4" >3814994.6182</td>
#       <td id="T_03b05_row2_col5" class="data row2 col5" >1.9146</td>
#       <td id="T_03b05_row2_col6" class="data row2 col6" >0.9582</td>
#       <td id="T_03b05_row2_col7" class="data row2 col7" >-0.1304</td>
#     </tr>
#     <tr>
#       <th id="T_03b05_level0_row3" class="row_heading level0 row3" >SD</th>
#       <td id="T_03b05_row3_col0" class="data row3 col0" >NaT</td>
#       <td id="T_03b05_row3_col1" class="data row3 col1" >9.2042</td>
#       <td id="T_03b05_row3_col2" class="data row3 col2" >11.4076</td>
#       <td id="T_03b05_row3_col3" class="data row3 col3" >779241.0116</td>
#       <td id="T_03b05_row3_col4" class="data row3 col4" >2535095.0536</td>
#       <td id="T_03b05_row3_col5" class="data row3 col5" >0.0003</td>
#       <td id="T_03b05_row3_col6" class="data row3 col6" >0.1361</td>
#       <td id="T_03b05_row3_col7" class="data row3 col7" >0.0880</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# Contoh: Forecast 12 periode ke depan
forecast = predict_model(final_model, fh=12)

# Menampilkan hasil prediksi
print(forecast)
# Out:
#                y_pred
# 2022-07  1.476819e+06
# 2022-08  1.541162e+06
# 2022-09  1.535821e+06
# 2022-10  1.536264e+06
# 2022-11  1.536227e+06
# 2022-12  1.536230e+06
# 2023-01  1.536230e+06
# 2023-02  1.536230e+06
# 2023-03  1.536230e+06
# 2023-04  1.536230e+06
# 2023-05  1.536230e+06
# 2023-06  1.536230e+06

# %%
plot_model(final_model, plot='forecast')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9ef08034-2c00-40d8-a68b-c84c578e19c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ef08034-2c00-40d8-a68b-c84c578e19c5")) {                    Plotly.newPlot(                        "9ef08034-2c00-40d8-a68b-c84c578e19c5",                        [{"line":{"color":"#1f77b4"},"marker":{"size":5},"mode":"lines+markers","name":"Forecast | ARIMA","showlegend":true,"x":["2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00"],"y":[1476818.5222,1541162.04,1535820.8071,1536264.1893,1536227.3836,1536230.4389],"type":"scatter"},{"line":{"width":0},"marker":{"color":"#68BBE3"},"mode":"lines","name":"Lower Interval","showlegend":false,"x":["2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00"],"y":[-4526680.3983,-4482986.0041,-4488469.2816,-4488026.8783,-4488063.6907,-4488060.6355],"type":"scatter"},{"fill":"tonexty","fillcolor":"rgba(104,187,227,0.5)","line":{"width":0},"marker":{"color":"#68BBE3"},"mode":"lines","name":"Prediction Interval | ARIMA","showlegend":true,"x":["2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00"],"y":[7480317.4427,7565310.0841,7560110.8959,7560555.2569,7560518.4579,7560521.5132],"type":"scatter"},{"marker":{"color":"#3f3f3f","size":5},"mode":"lines+markers","name":"Original","showlegend":true,"x":["2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00"],"y":[613932,0,11600,29000,82922,58000,98066,58000,664788,29000,15595615,5800,424640,203882,802167,2180078,3767939,2251937,2302902,319784,127617,323149,890001,2393962],"type":"scatter"}],                        {"title":{"text":"Actual vs. 'Out-of-Sample' Forecast | discount_amount"},"xaxis":{"title":{"text":"Time"}},"yaxis":{"title":{"text":"Values"}},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(51,51,51)"},"error_y":{"color":"rgb(51,51,51)"},"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"baxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar": ...

# %%
plot_model(final_model, plot='residuals')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="88ea808d-9bb9-4dac-a4ca-ac8bcf7637d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88ea808d-9bb9-4dac-a4ca-ac8bcf7637d5")) {                    Plotly.newPlot(                        "88ea808d-9bb9-4dac-a4ca-ac8bcf7637d5",                        [{"line":{"color":"rgb(31, 119, 180)","width":2},"marker":{"color":"rgb(31, 119, 180)","size":5},"mode":"lines+markers","name":"discount_amount","x":["2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00"],"y":[613932,0,11600,29000,82922,58000,98066,58000,664788,29000,15595615,5800,424640,203882,802167,2180078,3767939,2251937,2302902,319784,127617,323149,890001,2393962],"type":"scattergl","xaxis":"x","yaxis":"y"},{"line":{"color":"rgb(255, 127, 14)","width":2},"marker":{"color":"rgb(255, 127, 14)","size":5},"mode":"lines+markers","name":"ARIMA","x":["2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00"],"y":[-922298.2046999999,-1612791.2888,-1652154.523,-1633791.5931,-1578425.1981,-1598871.068,-1560873.8732,-1597613.9463,-994151.8732,-1579569.671,13934267.8019,-363343.7508,-1238633.0581,-1424622.6455,-844663.0327999999,582912.3251,2285155.3756999997,900963.6285000001,null,null,null,null,null,null],"type":"scattergl","xaxis":"x","yaxis":"y"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(51,51,51)"},"error_y":{"color":"rgb(51,51,51)"},"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"baxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmap"}],"histogram2dcontour":[ ...
